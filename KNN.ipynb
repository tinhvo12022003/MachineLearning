# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import time as time

# %%
DATA = pd.read_csv('iris_data.csv')
print(DATA)
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth            nhan
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
DATA_TRAINING = DATA[['sepalLength', 'sepalWidth', 'petalLength', 'petalWidth']]
LABELS = DATA['nhan']
print(DATA_TRAINING)
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(DATA_TRAINING, LABELS, train_size=0.8, test_size=0.2)

for i in range(1, 20, 2):
    start_time = time.time()
    print('With K = {}'.format(i))
    #process training data
    knn = KNeighborsClassifier(n_neighbors=i, algorithm='ball_tree')
    knn.fit(X_train, y_train)
    end_time = time.time()
    time_run = end_time - start_time
    #predicted
    print("Run time = {}".format(time_run))
    predicted = knn.predict(X_test)
    acc = accuracy_score(y_test, predicted)
    print("Accuracy: {}%".format(round(acc * 100), digits=3))

    #print confusion matrix map
    cm = confusion_matrix(y_test, predicted)
    sns.heatmap(cm, annot=True, fmt='d')
    plt.ylabel(np.array(['Iris-setosa', 'Iris-virginica', 'Iris-versicolor']))
    plt.xlabel(np.array(['Iris-setosa', 'Iris-virginica', 'Iris-versicolor']))
    plt.show()
# Out:
# With K = 1
# Run time = 0.0076143741607666016
# Accuracy: 97%
# With K = 3
# Run time = 0.009948968887329102
# Accuracy: 97%
# With K = 5
# Run time = 0.0
# Accuracy: 97%
# With K = 7
# Run time = 0.0
# Accuracy: 97%
# With K = 9
# Run time = 0.002016782760620117
# Accuracy: 97%
# With K = 11
# Run time = 0.0
# Accuracy: 97%
# With K = 13
# Run time = 0.0019991397857666016
# Accuracy: 97%
# With K = 15
# Run time = 0.006842613220214844
# Accuracy: 97%
# With K = 17
# Run time = 0.001659393310546875
# Accuracy: 97%
# With K = 19
# Run time = 0.0
# Accuracy: 100%
